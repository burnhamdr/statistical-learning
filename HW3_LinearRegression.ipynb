# %% [markdown]
# # Mathematical exercises
#
# Solutions to the following exercises may be either typed into the submitted Jupyter notebook, or handwritten solutions may be scanned and submitted as a separate PDF file.

# %% [markdown]
# **Exercise 1** (3 points): Problem 3.11 from the PRML textbook.<br />
# <br />
# $\sigma_{N}^{2}(\mathbf{x}) = \frac{1}{\beta} + \mathbf{\phi}(\mathbf{x})^{\intercal}\mathbf{S}_{N}\mathbf{\phi}(\mathbf{x})$ (3.59) satisfies $\sigma_{N + 1}^{2}(\mathbf{x}) \leq \sigma_{N}^{2}(\mathbf{x})$ (3.111)<br />
# <br />
# From class: $S_{N}^{-1} = S_{o}^{-1} + \beta \mathbf{\Phi}^{\intercal}\mathbf{\Phi}$<br />
# <br />
# $S_{N+1}^{-1} = S_{N}^{-1} + \beta \mathbf{\Phi(x_{N+1})}^{\intercal}\mathbf{\Phi(x_{N+1})}$<br />
# <br />
# To get $S_{N+1}$ use matrix identity: $S_{N+1} = [S_{N+1}^{-1}]^{-1} = [S_{N}^{-1} + \beta \mathbf{\Phi(x_{N+1})}^{\intercal}\mathbf{\Phi(x_{N+1})}]^{-1}$<br />
# <br />
# $S_{N+1} = [S_{N}^{-1} + \sqrt{\beta} \mathbf{\Phi(x_{N+1})}^{\intercal}\sqrt{\beta}\mathbf{\Phi(x_{N+1})}]^{-1}$ Now in form $(\mathbf{M} + \mathbf{v}\mathbf{v}^{\intercal})$<br />
# <br />
# $S_{N+1} = S_{N} - \frac{S_{N}[\sqrt{\beta} \mathbf{\Phi(x_{N+1})}^{\intercal}\sqrt{\beta}\mathbf{\Phi(x_{N+1})}]S_{N}}{1 + \sqrt{\beta} \mathbf{\Phi(x_{N+1})}^{\intercal}S_{N}\sqrt{\beta}\mathbf{\Phi(x_{N+1})}}$ factor out $\beta$<br />
# <br />
# $S_{N+1} = S_{N} - \frac{S_{N}[ \mathbf{\Phi(x_{N+1})}^{\intercal}\mathbf{\Phi(x_{N+1})}]S_{N}}{\frac{1}{\beta} +  \mathbf{\Phi(x_{N+1})}^{\intercal}S_{N}\mathbf{\Phi(x_{N+1})}}$<br />
# <br />
# $\sigma_{N+1}^{2} = \frac{1}{\beta} + \mathbf{\Phi}(x)S_{N+1}\mathbf{\Phi}(x)^{\intercal}$<br />
# <br />
# $\sigma_{N+1}^{2} = \frac{1}{\beta} + \mathbf{\Phi}(x)\left(S_{N} - \frac{S_{N}[ \mathbf{\Phi(x_{N+1})}^{\intercal}\mathbf{\Phi(x_{N+1})}]S_{N}}{\frac{1}{\beta} +  \mathbf{\Phi(x_{N+1})}^{\intercal}S_{N}\mathbf{\Phi(x_{N+1})}}\right)\mathbf{\Phi}(x)^{\intercal}$<br />
# <br />
# $\sigma_{N+1}^{2} = \frac{1}{\beta} + \sigma_{N}^{2}\ - \left(\frac{\mathbf{\Phi}(x)S_{N}\mathbf{\Phi(x_{N+1})}^{\intercal}\mathbf{\Phi(x_{N+1})}S_{N}\mathbf{\Phi}(x)^{\intercal}}{\frac{1}{\beta} +  \mathbf{\Phi(x_{N+1})}^{\intercal}S_{N}\mathbf{\Phi(x_{N+1})}}\right)$<br />
# <br />
# $\sigma_{N+1}^{2} = \frac{1}{\beta} + \sigma_{N}^{2}\ - \left(\frac{[\mathbf{\Phi}(x)S_{N}\mathbf{\Phi(x_{N+1})}]^{2}}{\frac{1}{\beta} +  \mathbf{\Phi(x_{N+1})}^{\intercal}S_{N}\mathbf{\Phi(x_{N+1})}}\right)$<br />
# <br />
# $S_{N}$ is positive definite so the fraction on the right hand side will therefor be positive and $\sigma_{N+1}^{2}$ will then be less than $\sigma_{N}^{2}$.

# %% [markdown]
# **Exercise 2** (3 points): In class we used the following formula for matrix inversion:
# $$
# (A^{-1} + \vec{u}\vec{v}^\top)^{-1} = A - \frac{A \vec{u} \vec{v}^\top A}{1 + \vec{v}^T A \vec{u}}
# $$
# where $A$ is an invertible matix. In addition to helping us prove our result about Bayesian regression, this formula is often useful because, although computing a matrix inverse is computationally costly in general, if we are just adding a rank-one perturbation to a matrix whose inverse we already know, inverting the new matrix is not so costly. Prove the above formula.

# %% [markdown]
# $B = A - \frac{A \vec{u} \vec{v}^\top A}{1 + \vec{v}^T A \vec{u}}$ and $C = (A^{-1} + \vec{u}\vec{v}^\top)^{-1}$, show $C^{-1}B = I$<br />
# <br />
# $I = (A^{-1} + \vec{u}\vec{v}^\top)A - \frac{(A^{-1} + \vec{u}\vec{v}^\top)A \vec{u} \vec{v}^\top A}{1 + \vec{v}^T A \vec{u}}$<br />
# <br />
# $I = A^{-1}A + \vec{u}\vec{v}^\top A - \frac{A^{-1}A \vec{u} \vec{v}^\top A + \vec{u}\vec{v}^\top A \vec{u} \vec{v}^\top A}{1 + \vec{v}^T A \vec{u}}$<br />
# <br />
# $I = I + \vec{u}\vec{v}^\top A - \frac{\vec{u} \vec{v}^\top A + \vec{u}\vec{v}^\top A \vec{u} \vec{v}^\top A}{1 + \vec{v}^T A \vec{u}}$<br />
# <br />
# $I = I + \vec{u}\vec{v}^\top A - \frac{\vec{u} [\vec{v}^\top A + \vec{v}^\top A \vec{u} \vec{v}^\top A]}{1 + \vec{v}^T A \vec{u}}$<br />
# <br />
# $I = I + \vec{u}\vec{v}^\top A - \frac{\vec{u} [1 + \vec{v}^\top A \vec{u} ]\vec{v}^\top A}{1 + \vec{v}^T A \vec{u}}$<br />
# <br />
# $I = I + \vec{u}\vec{v}^\top A - \vec{u}\vec{v}^\top A$<br />
# <br />
# $I = I$<br />

# %% [markdown]
# # Coding exercises
#
# Reminder: Once your notebook is complete, you should restart the kernel, run all of the cells in order, and make sure that no errors occur. Notebooks that run successfully without errors will be awarded one extra credit point.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Linear regression with regularization
#
# Let us return to the regression problem that we studied in the first homework assignment. In that assignment, we showed that cross-validation, i.e. splitting data into training and testing sets, can be an effective strategy to combat overfitting. In this assignment, we'll look at another strategy to combat overfitting: regularization.
#
# As before, let's make some fake data from a sine wave with added noise.

# %%
n = 40  # number of data points

# Simulated data:
x_data = 2*np.pi*np.random.rand(n)
noise_amp = 0.3
noise = noise_amp*np.random.randn(n)
y_data = np.sin(x_data) + noise

plt.plot(x_data, y_data, 'o')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Next, as in our class demo, let's create polynomial feature vectors from the data and plot the prediction curve:

# %%
m = 10  # number of feature vectors (i.e. m-1 is the order of the polynomial)
alpha = 0.0  # regularization parameter

# Create the design matrix:
phi = np.zeros((n, m))
for j in range(m):
    phi[:,j] = x_data**j

# The weight vector minimizing the mean squared error:
w = np.linalg.inv(alpha*np.eye(m) + phi.T @ phi) @ phi.T @ y_data

# To plot the prediction curve, create an array of x data and corresponding y data:
x_array = np.arange(0, 2*np.pi, 0.01)
y_pred = np.zeros_like(x_array)
for i, x in enumerate(x_array):
    y_pred[i] = np.sum([w[j]*x**j for j in range(m)])
    
plt.plot(x_array, y_pred)
plt.plot(x_data, y_data, 'o')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# **Exercise 1** (3 pts): Turn the above block of code into a function, `mse(x_data, y_data, m, alpha)`, that fits a polynomial with `m` parameters to data with regularization parameter `alpha`, as in the above block of code, and returns the MSE. Use this function to plot the MSE for different values of `alpha`, using `plt.semilogx()` to scale the x-axis logarithmically. Explain why the curve that you plot looks the way that it does.

# %%
## Solution ##
def mse(x_data, y_data, m, alpha):
    n = len(x_data)
    # Create the design matrix:
    phi = np.zeros((n, m))
    for j in range(m):
        phi[:,j] = x_data**j

    # The weight vector minimizing the mean squared error:
    w = np.linalg.inv(alpha*np.eye(m) + phi.T @ phi) @ phi.T @ y_data

    # To plot the prediction curve, create an array of x data and corresponding y data:
    # x_array = np.arange(0, 2*np.pi, 0.01)
    y_pred = np.zeros_like(x_data)
    for i, x in enumerate(x_data):
        y_pred[i] = np.sum([w[j]*x**j for j in range(m)])

    mse_ = np.sum((y_data - y_pred)**2)*(1/len(y_data))


    return y_pred, mse_

alpha_list = [c/(10**i) for i in range(-8,3) for c in [1, 5]]
m = 10
mse_list = []
for alpha in alpha_list:
    y_pred, mse_ = mse(x_data, y_data, m, alpha)
    mse_list.append(mse_)

plt.semilogx(alpha_list, mse_list, 'o')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# **Exercise 2** (3 points): Create another version of the function from above, calling the new version `mse_cv(x_data, y_data, m, alpha, cv, make_plot)`, that takes two new Boolean arguments.
# - If `cv=True`, perform cross-validation by splitting the data into training and testing sets and performing the fit with just the training data. The function should return both the MSE computed with the training data and the MSE computed with the testing data.
# - If `make_plot=True`, plot the data together with the fit. If cross-validation is used, plot the training and testing data in separate colors, with a legend to distinguish them.

# %%
## Solution  ##
def mse_cv(x_data, y_data, m, alpha, cv=False, make_plot=False):
    if cv:
        split = 0.5
        train_x = x_data[:int(len(x_data)*split)]
        test_x = x_data[int(len(x_data)*split):]

        train_y = y_data[:int(len(y_data)*split)]
        test_y = y_data[int(len(y_data)*split):]
        n = len(train_x)
    else:
        n = len(x_data)
        train_x = x_data
        train_y = y_data

    # Create the design matrix:
    phi = np.zeros((n, m))
    for j in range(m):
        phi[:,j] = train_x**j

    # The weight vector minimizing the mean squared error:
    w = np.linalg.inv(alpha*np.eye(m) + phi.T @ phi) @ phi.T @ train_y

    if cv:
        y_pred_train = np.zeros_like(train_x)
        y_pred_test = np.zeros_like(test_x)
        for i, x in enumerate(train_x):
            y_pred_train[i] = np.sum([w[j]*x**j for j in range(m)])
        for i, x in enumerate(test_x):
            y_pred_test[i] = np.sum([w[j]*x**j for j in range(m)])

        mse_train = np.sum((train_y - y_pred_train)**2)*(1/len(train_y))
        mse_test = np.sum((test_y - y_pred_test)**2)*(1/len(test_y))

        mse_ = {'train': mse_train, 'test': mse_test}
        x_array = np.arange(0, 2*np.pi, 0.01)
        y_pred = np.zeros_like(x_array)
        for i, x in enumerate(x_array):
            y_pred[i] = np.sum([w[j]*x**j for j in range(m)])

        if make_plot:
            fig, ax = plt.subplots(figsize=(12,8))
            ax.plot(x_array, y_pred)
            ax.plot(train_x, train_y, 'o',alpha=0.3,label='Train')
            ax.plot(test_x, test_y, 'o',alpha=0.3,label='Test')
            ax.set_xlabel('x')
            ax.set_ylabel('y')
            ax.legend()
            plt.show()

    else:
        # To plot the prediction curve, create an array of x data and corresponding y data:
        y_pred = np.zeros_like(x_data)
        for i, x in enumerate(x_data):
            y_pred[i] = np.sum([w[j]*x**j for j in range(m)])
        mse_ = np.sum((train_y - y_pred)**2)*(1/len(train_y))

        if make_plot:
            x_array = np.arange(0, 2*np.pi, 0.01)
            fig, ax = plt.subplots(figsize=(12,8))
            plt.plot(x_array, y_pred)
            plt.plot(x_data, y_data, 'o')
            plt.xlabel('x')
            plt.ylabel('y')
            plt.show()
    return y_pred, mse_

y_pred, mse_ = mse_cv(x_data, y_data, m, alpha=10, cv=True, make_plot=True)

# %% [markdown]
# **Exercise 3** (3 points): Use the above function to make a plot of both the training and testing MSE for various values of `alpha`. (This will work best if the values are evenly spaced on a log scale.) Report the value of `alpha` (an approximate value is fine) that minimizes the testing MSE. Finally, use the `make_plot` option in the function above to make two plots of the data along with the fits, where one fit doesn't use regularization, and the other fit uses the optimal value that was just found.

# %%
## Solution ##
# alpha_list = [0,1,10,100,1000]  # regularization parameter
alpha_list = [c/(10**i) for i in range(-8,3) for c in [1, 5]]
m = 10
test_mse_list = []
train_mse_list = []
for alpha in alpha_list:
    y_pred, mse_ = mse_cv(x_data, y_data, m, alpha, cv=True)
    train_mse_list.append(mse_['train'])
    test_mse_list.append(mse_['test'])

fig, ax = plt.subplots(figsize=(12,8))
ax.semilogx(alpha_list, train_mse_list, 'o',label='Train')
ax.semilogx(alpha_list, test_mse_list, 'o',label='Test')
ax.set_xlabel('x')
ax.set_ylabel('MSE')
ax.set_title('MSE by Alpha Value')
ax.legend()
plt.show()
min_test_mse = test_mse_list.index(min(test_mse_list))
alpha_opt = alpha_list[min_test_mse]
print("Best alpha: " + str(alpha_opt))
# Out:
# Best alpha: 0.1

# %%
## Solution ##
min_test_mse = test_mse_list.index(min(test_mse_list))
alpha_opt = alpha_list[min_test_mse]
alphas = [0, alpha_opt]#list of no regularization alpha and optimal alpha
fig, ax = plt.subplots(figsize=(12,8))
x_array = np.arange(0, 2*np.pi, 0.01)
for alpha in alphas:#only take first two values
    y_pred, mse_ = mse_cv(x_data, y_data, m, alpha, cv=True)
    label = r'$\alpha = $' + str(alpha)
    ax.plot(x_array, y_pred, label=label)

ax.plot(x_data, y_data, 'o',color='k',alpha=0.3)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Regularaization Fit Comparison')
ax.legend()
plt.show()

# %% [markdown]
# ## Linear regression with a built-in function
#
# Now let's get the same results with less work using a built-in package.
#
# **Exercise 4** (3 points): Read the documentation for `linear_model.LinearRegression()` from the `sklearn` library, which contains implementations of lots of standard machine algorithms. Following the example in the documentation, and without using regularization, fit a linear model to the first half of our data, then use the `.score()` method to quantify the goodness of fit for both the training set and the testing set. (Note that the score being returned by this function is given by $r^2 = 1 - \mathrm{MSE}/\sigma^2$, where $\sigma^2$ is the variance of the data along the y dimension. This means that scores close to 1 are very good, while negative scores or scores close to zero are bad.) Plot the fit along with the data, with the training and testing data in different colors. The result should match the plot we made above.

# %%
from sklearn import linear_model

# %%
## Solution ##
m=10
split=0.5
train_x = x_data[:int(len(x_data)*split)]
train_y = y_data[:int(len(x_data)*split)]
test_x = x_data[int(len(x_data)*split):]
test_y = y_data[int(len(x_data)*split):]

# Create the design matrix:
phi = np.zeros((n, m))
for j in range(m):
    phi[:,j] = x_data**j


reg = linear_model.LinearRegression().fit(phi[:int(len(x_data)*split), :], train_y)
train_score = reg.score(phi[:int(len(x_data)*split),:], train_y)
test_score = reg.score(phi[int(len(x_data)*split):,:], test_y)

fig, ax = plt.subplots(figsize=(12,8))
x_array = np.arange(0, 2*np.pi, 0.01)
phi_pred = np.zeros((len(x_array), m))
for j in range(m):
    phi_pred[:,j] = x_array**j

y_pred = reg.predict(phi_pred)
ax.plot(x_array, y_pred)
label='Train, ' + r'$R^{2} = $' + str(round(train_score, 2))
ax.plot(train_x, train_y, 'o',label=label,alpha=0.3)
label='Test, ' + r'$R^{2} = $' + str(round(test_score, 2))
ax.plot(test_x, test_y, 'o',label=label,alpha=0.3)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()
ax.set_title('Sklearn Linear Model Fit')
plt.show()

# %% [markdown]
# **Exercise 5** (3 points): Repeat the previous exercise, now using `linear_model.RidgeCV()`, which uses ridge regression (i.e. regularized just as with our `alpha` parameter above) with built-in cross validation (i.e. cross-validation is used to select the best regularization value as we did above, then the result is reported using this optimal value). You should find that the scores for the training and testing datasets are much more similar than before.

# %%
## Solution ##
split=0.5
m=10
split=0.5
train_x = x_data[:int(len(x_data)*split)]
train_y = y_data[:int(len(x_data)*split)]
test_x = x_data[int(len(x_data)*split):]
test_y = y_data[int(len(x_data)*split):]

# Create the design matrix:
phi = np.zeros((n, m))
for j in range(m):
    phi[:,j] = x_data**j


reg = linear_model.RidgeCV().fit(phi[:int(len(x_data)*split), :], train_y)
train_score = reg.score(phi[:int(len(x_data)*split),:], train_y)
test_score = reg.score(phi[int(len(x_data)*split):,:], test_y)


fig, ax = plt.subplots(figsize=(12,8))
x_array = np.arange(0, 2*np.pi, 0.01)
phi_pred = np.zeros((len(x_array), m))
for j in range(m):
    phi_pred[:,j] = x_array**j

y_pred = reg.predict(phi_pred)
ax.plot(x_array, y_pred)
label='Train, ' + r'$R^{2} = $' + str(round(train_score, 2))
ax.plot(train_x, train_y, 'o',label=label,alpha=0.3)
label='Test, ' + r'$R^{2} = $' + str(round(test_score, 2))
ax.plot(test_x, test_y, 'o',label=label,alpha=0.3)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()
ax.set_title('RidgeCV Model Fit')
plt.show()
